# %%
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method fgsm --epsilon 0.031 --gpu-id 4
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5136
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5108
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5118
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5097
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5014
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5127
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5064
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5106
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5046
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5050
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5071
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5061
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5064
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5024
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5057
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5052
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5097
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5097
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5098
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5074
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5103
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5085
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5072
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5007
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5086
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5090
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5113
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5063
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5090
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5119
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5134
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5101
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5081
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5078
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5121
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5138
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5112
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5101
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5093
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5123
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5075
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5142
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5115
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5112
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5059
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5161
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5105
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5085
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5089
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  5109
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  5138
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  5107
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  5151
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  5119
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          410571 function calls (393527 primitive calls) in 67.514 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20300   36.494    0.002   36.494    0.002 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   22.453    3.742   22.453    3.742 {built-in method numpy.core.multiarray.array}
#         4    2.736    0.684    2.736    0.684 {built-in method posix.fork}
#        10    1.698    0.170    1.698    0.170 {built-in method posix.waitpid}
#       100    0.690    0.007    0.690    0.007 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         1    0.647    0.647   67.509   67.509 Attack_Foolbox_ResNet20.py:4(<module>)
#      4600    0.394    0.000    0.394    0.000 {built-in method conv2d}
#      1781    0.340    0.000    0.340    0.000 {method 'update' of '_hashlib.HASH' objects}
#      1800    0.263    0.000    1.280    0.001 nagpreresnet_learned_v2.py:39(forward)
#      3800    0.246    0.000    0.246    0.000 {built-in method batch_norm}
#       192    0.195    0.001    0.195    0.001 {method 'read' of '_io.BufferedReader' objects}
# 16100/300    0.140    0.000    1.452    0.005 module.py:537(__call__)
#      3800    0.103    0.000    0.103    0.000 {built-in method relu_}
#         6    0.092    0.015    0.092    0.015 {built-in method _pickle.load}
#     20300    0.072    0.000    0.072    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#     20000    0.060    0.000    0.060    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#     40760    0.059    0.000    0.059    0.000 module.py:577(__getattr__)
#       427    0.058    0.000    0.058    0.000 {method 'cuda' of 'torch._C._TensorBase' objects}
#      1400    0.045    0.000    0.045    0.000 {built-in method posix.read}
#     60384    0.042    0.000    0.042    0.000 {method 'append' of 'list' objects}
#       100    0.039    0.000    0.039    0.000 {method 'poll' of 'select.poll' objects}
#      3800    0.037    0.000    0.335    0.000 batchnorm.py:58(forward)
#     16100    0.028    0.000    0.028    0.000 {built-in method torch._C._get_tracing_state}
#      4600    0.021    0.000    0.418    0.000 conv.py:332(conv2d_forward)
#     33667    0.020    0.000    0.020    0.000 {method 'values' of 'collections.OrderedDict' objects}
# 32781/32780    0.020    0.000    0.020    0.000 {built-in method builtins.len}
#      3800    0.017    0.000    0.272    0.000 functional.py:1629(batch_norm)
#      4600    0.015    0.000    0.439    0.000 conv.py:342(forward)
#       100    0.014    0.000    1.581    0.016 attack_toolbox.py:86(fgsm)
#       200    0.014    0.000    0.014    0.000 {built-in method addmm}
#       101    0.012    0.000    0.023    0.000 sampler.py:198(__iter__)
#       400    0.012    0.000    0.022    0.000 hmac.py:26(__init__)
#  1400/600    0.012    0.000    1.316    0.002 container.py:90(forward)
#       800    0.012    0.000    0.012    0.000 {built-in method posix.write}
#      2419    0.012    0.000    0.019    0.000 module.py:593(__setattr__)
#       200    0.011    0.000    0.011    0.000 {method 'recvmsg' of '_socket.socket' objects}
#       200    0.010    0.000    1.434    0.007 nagpreresnet_learned_v2.py:165(forward)
#        12    0.010    0.001    0.010    0.001 {built-in method io.open}
#       200    0.010    0.000    0.010    0.000 {built-in method clamp}
#      3800    0.009    0.000    0.119    0.000 activation.py:93(forward)
#       200    0.008    0.000    0.008    0.000 {method 'connect' of '_socket.socket' objects}
#       416    0.008    0.000    0.008    0.000 {built-in method tensor}
#       200    0.008    0.000    0.008    0.000 {built-in method torch._C._nn.avg_pool2d}
#      3800    0.008    0.000    0.110    0.000 functional.py:903(relu)
#       100    0.007    0.000    0.216    0.002 {built-in method _pickle.loads}
#        67    0.007    0.000    0.015    0.000 module.py:718(_load_from_state_dict)
#         1    0.007    0.007    0.007    0.007 {built-in method numpy.core.multiarray.concatenate}
#      3800    0.006    0.000    0.009    0.000 batchnorm.py:241(_check_input_dim)
#      1400    0.006    0.000    0.053    0.000 connection.py:374(_recv)
#      8873    0.006    0.000    0.006    0.000 {built-in method builtins.isinstance}
#      3800    0.006    0.000    0.009    0.000 __init__.py:461(__get__)
#       100    0.005    0.000    0.005    0.000 {built-in method torch._C._nn.nll_loss}
#       197    0.005    0.000    0.005    0.000 {method 'acquire' of '_thread.lock' objects}
#      9217    0.005    0.000    0.005    0.000 {method 'startswith' of 'str' objects}
#       400    0.005    0.000    0.005    0.000 socket.py:139(__init__)
#        20    0.005    0.000    0.005    0.000 {built-in method posix.stat}
#      7422    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#       200    0.005    0.000    0.021    0.000 connection.py:607(SocketClient)
#       100    0.004    0.000    0.004    0.000 {method 'sign_' of 'torch._C._TensorBase' objects}
#       100    0.004    0.000    0.004    0.000 {method 'log_softmax' of 'torch._C._TensorBase' objects}
#       397    0.004    0.000    0.004    0.000 {method 'set_' of 'torch._C._TensorBase' objects}
#       200    0.004    0.000    0.157    0.001 resource_sharer.py:82(get_connection)
#       200    0.004    0.000    0.199    0.001 reductions.py:273(rebuild_storage_fd)
#       600    0.004    0.000    0.019    0.000 connection.py:181(send_bytes)
#       700    0.004    0.000    0.059    0.000 connection.py:406(_recv_bytes)
#      4144    0.003    0.000    0.003    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#      3800    0.003    0.000    0.003    0.000 {built-in method torch._C._get_cudnn_enabled}
#       200    0.003    0.000    0.080    0.000 connection.py:729(answer_challenge)
#       100    0.003    0.000    0.003    0.000 {built-in method ones_like}
#        21    0.003    0.000    0.003    0.000 {method 'normal_' of 'torch._C._TensorBase' objects}
#       200    0.003    0.000    0.003    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#       800    0.003    0.000    0.018    0.000 connection.py:390(_send_bytes)
#       700    0.003    0.000    0.063    0.000 connection.py:208(recv_bytes)
#       200    0.003    0.000    0.015    0.000 reduction.py:149(recvfds)
#       178    0.003    0.000    0.003    0.000 {method '_set_from_file' of 'torch._C.CudaFloatStorageBase' objects}
#        37    0.003    0.000    0.003    0.000 socket.py:342(send)
#       127    0.003    0.000    0.003    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#         1    0.003    0.003    0.003    0.003 {built-in method builtins.compile}
#       100    0.003    0.000    0.003    0.000 {built-in method _new_shared_fd}
#       168    0.003    0.000    0.016    0.000 module.py:77(_construct)
#       100    0.003    0.000    0.278    0.003 queues.py:91(get)
#       800    0.003    0.000    0.003    0.000 {built-in method _hashlib.new}
#        23    0.003    0.000    0.003    0.000 {method 'uniform_' of 'torch._C._TensorBase' objects}
#       414    0.003    0.000    0.003    0.000 {built-in method posix.close}
#       200    0.002    0.000    0.004    0.000 reduction.py:38(__init__)
#      1340    0.002    0.000    0.004    0.000 {built-in method builtins.hasattr}
#       200    0.002    0.000    0.137    0.001 connection.py:478(Client)
#       400    0.002    0.000    0.002    0.000 {built-in method posix.fstat}
#       200    0.002    0.000    0.031    0.000 connection.py:716(deliver_challenge)
#       197    0.002    0.000    0.008    0.000 serialization.py:93(_cuda_deserialize)
#       100    0.002    0.000    0.050    0.001 connection.py:897(wait)
#       210    0.002    0.000    0.002    0.000 connection.py:117(__init__)
#       397    0.002    0.000    0.014    0.000 _utils.py:128(_rebuild_tensor)
#       200    0.002    0.000    0.002    0.000 {method 't' of 'torch._C._TensorBase' objects}
#       200    0.002    0.000    0.182    0.001 resource_sharer.py:55(detach)
#       101    0.002    0.000    2.010    0.020 dataloader.py:775(__next__)
#       108    0.002    0.000    0.035    0.000 dataloader.py:823(_try_put_index)
#       200    0.002    0.000    0.020    0.000 reduction.py:179(recv_handle)
#       114    0.002    0.000    0.002    0.000 {method 'release' of '_thread.lock' objects}
#       800    0.002    0.000    0.014    0.000 connection.py:365(_send)
#         7    0.002    0.000    0.410    0.059 utils.py:24(calculate_md5)
#       104    0.002    0.000    0.010    0.000 queues.py:80(put)
#       200    0.002    0.000    0.002    0.000 {method 'update' of 'dict' objects}
#       800    0.002    0.000    0.005    0.000 hmac.py:52(<lambda>)
#         1    0.002    0.002    0.018    0.018 {method 'load' of '_pickle.Unpickler' objects}
#       100    0.002    0.000    0.807    0.008 attack_toolbox.py:26(get_loss)
#      1900    0.001    0.000    0.001    0.000 connection.py:134(_check_closed)
#       200    0.001    0.000    0.007    0.000 reduction.py:48(dumps)
#       197    0.001    0.000    0.011    0.000 serialization.py:520(persistent_load)
#       200    0.001    0.000    0.010    0.000 reductions.py:79(rebuild_tensor)
#       200    0.001    0.000    0.017    0.000 functional.py:1354(linear)
#       100    0.001    0.000    0.774    0.008 Attack_Foolbox_ResNet20.py:104(predict)
#       800    0.001    0.000    0.004    0.000 hashlib.py:139(__hash_new)
#       108    0.001    0.000    0.004    0.000 threading.py:334(notify)
#       200    0.001    0.000    0.013    0.000 connection.py:202(send)
#        20    0.001    0.000    0.004    0.000 synchronize.py:50(__init__)
#       100    0.001    0.000    0.005    0.000 __init__.py:20(_make_grads)
#      1400    0.001    0.000    0.001    0.000 {method 'write' of '_io.BytesIO' objects}
#       400    0.001    0.000    0.023    0.000 hmac.py:133(new)
#       200    0.001    0.000    0.019    0.000 linear.py:86(forward)
#       400    0.001    0.000    0.003    0.000 hmac.py:108(_current)
#       100    0.001    0.000    0.001    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#       700    0.001    0.000    0.001    0.000 {built-in method _struct.unpack}
#       100    0.001    0.000    0.003    0.000 selectors.py:233(register)
#       100    0.001    0.000    0.041    0.000 selectors.py:365(select)
#       200    0.001    0.000    0.001    0.000 {method 'dump' of '_pickle.Pickler' objects}
#      67/1    0.001    0.000    0.006    0.006 module.py:206(_apply)
#       100    0.001    0.000    0.696    0.007 __init__.py:38(backward)
#       197    0.001    0.000    0.004    0.000 serialization.py:68(validate_cuda_device)
#       100    0.001    0.000    0.007    0.000 functional.py:1770(nll_loss)
#       200    0.001    0.000    0.009    0.000 pooling.py:549(forward)
#       200    0.001    0.000    0.003    0.000 reductions.py:48(__setitem__)
#       100    0.001    0.000    0.697    0.007 tensor.py:90(backward)
#       200    0.001    0.000    0.001    0.000 {built-in method posix.urandom}
#       546    0.001    0.000    0.001    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#       100    0.001    0.000    0.052    0.001 connection.py:253(poll)
#       208    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       400    0.001    0.000    0.003    0.000 reductions.py:258(fd_id)
#       400    0.001    0.000    0.004    0.000 hmac.py:117(digest)
#       800    0.001    0.000    0.001    0.000 {method 'digest' of '_hashlib.HASH' objects}
#       395    0.001    0.000    0.002    0.000 __init__.py:62(is_available)
#       400    0.001    0.000    0.001    0.000 connection.py:95(address_type)
#      1400    0.001    0.000    0.001    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#       169    0.001    0.000    0.001    0.000 {built-in method torch._C._log_api_usage_once}
#       200    0.001    0.000    0.001    0.000 socket.py:419(detach)
#       158    0.001    0.000    0.003    0.000 module.py:105(register_buffer)
#       100    0.001    0.000    0.002    0.000 selectors.py:346(__init__)
#       100    0.001    0.000    0.001    0.000 selectors.py:208(__init__)
#       800    0.001    0.000    0.001    0.000 {built-in method _struct.pack}
#       236    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#       800    0.001    0.000    0.001    0.000 {method 'translate' of 'bytes' objects}
#       200    0.001    0.000    0.001    0.000 reductions.py:26(__init__)
#       101    0.001    0.000    0.017    0.000 loss.py:909(__init__)
#         1    0.001    0.001    0.001    0.001 reductions.py:53(free_dead_references)
#       100    0.001    0.000    0.051    0.001 connection.py:413(_poll)
#       200    0.001    0.000    0.002    0.000 socket.py:454(fromfd)
#       200    0.001    0.000    0.001    0.000 reductions.py:266(storage_from_cache)
#       100    0.001    0.000    0.001    0.000 selectors.py:20(_fileobj_to_fd)
#       101    0.001    0.000    0.016    0.000 loss.py:18(__init__)
#       400    0.001    0.000    0.002    0.000 socket.py:151(__exit__)
#       100    0.001    0.000    0.013    0.000 loss.py:914(forward)
#       101    0.001    0.000    0.013    0.000 loss.py:9(__init__)
#       100    0.001    0.000    0.012    0.000 functional.py:1950(cross_entropy)
#       100    0.001    0.000    0.030    0.000 dataloader.py:842(_process_data)
#       719    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#       120    0.001    0.000    0.001    0.000 {method '__enter__' of '_thread.lock' objects}
#       800    0.001    0.000    0.001    0.000 connection.py:138(_check_readable)
#       100    0.001    0.000    0.004    0.000 selectors.py:350(register)
#       400    0.001    0.000    0.001    0.000 hmac.py:90(update)
#        19    0.001    0.000    0.006    0.000 batchnorm.py:19(__init__)
#       168    0.001    0.000    0.017    0.000 module.py:71(__init__)
#         4    0.001    0.000    2.737    0.684 popen_fork.py:63(_launch)
#        21    0.001    0.000    0.008    0.000 conv.py:18(__init__)
#       204    0.001    0.000    0.003    0.000 connection.py:173(close)
#       269    0.001    0.000    0.025    0.000 {built-in method builtins.next}
#       100    0.001    0.000    0.278    0.003 dataloader.py:711(_try_get_data)
#        23    0.001    0.000    0.001    0.000 init.py:202(_calculate_fan_in_and_fan_out)
#       100    0.001    0.000    0.002    0.000 fromnumeric.py:943(argmax)
#       100    0.001    0.000    0.279    0.003 dataloader.py:742(_get_data)
#       239    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#       800    0.001    0.000    0.001    0.000 connection.py:142(_check_writable)
#         1    0.001    0.001    2.757    2.757 dataloader.py:635(__init__)
#       197    0.001    0.000    0.009    0.000 serialization.py:117(default_restore_location)
#       200    0.001    0.000    0.001    0.000 {built-in method _socket.dup}
#       300    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#       100    0.000    0.000    0.698    0.007 Attack_Foolbox_ResNet20.py:155(get_gradient)
#       275    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#      67/1    0.000    0.000    0.016    0.016 module.py:822(load)
#       200    0.000    0.000    0.001    0.000 socket.py:413(close)
#       300    0.000    0.000    0.001    0.000 connection.py:168(fileno)
#       400    0.000    0.000    0.000    0.000 {method 'ljust' of 'bytes' objects}
#    309/68    0.000    0.000    0.001    0.000 module.py:1015(named_modules)
#       400    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#       204    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       100    0.000    0.000    0.002    0.000 fromnumeric.py:50(_wrapfunc)
#       200    0.000    0.000    0.000    0.000 socket.py:409(_real_close)
#        37    0.000    0.000    0.004    0.000 iostream.py:197(schedule)
#       266    0.000    0.000    0.001    0.000 module.py:959(children)
#       197    0.000    0.000    0.001    0.000 __init__.py:240(__enter__)
#         1    0.000    0.000    0.024    0.024 nagpreresnet_learned_v2.py:114(__init__)
#       200    0.000    0.000    0.003    0.000 connection.py:262(__exit__)
#       120    0.000    0.000    0.001    0.000 threading.py:239(__enter__)
#       266    0.000    0.000    0.001    0.000 module.py:968(named_children)
#       197    0.000    0.000    0.001    0.000 _utils.py:5(_get_device_index)
#         1    0.000    0.000    0.159    0.159 serialization.py:392(_load)
#         1    0.000    0.000   67.514   67.514 py3compat.py:184(execfile)
#       160    0.000    0.000    0.001    0.000 random.py:255(choice)
#       160    0.000    0.000    0.001    0.000 random.py:223(_randbelow)
#       100    0.000    0.000    0.000    0.000 selectors.py:268(close)
#       200    0.000    0.000    0.000    0.000 process.py:170(authkey)
#       197    0.000    0.000    0.005    0.000 _utils.py:134(_rebuild_tensor_v2)
#       188    0.000    0.000    0.063    0.000 utils.py:27(<lambda>)
#       200    0.000    0.000    0.000    0.000 {method 'setblocking' of '_socket.socket' objects}
#       261    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       236    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       394    0.000    0.000    0.001    0.000 serialization.py:509(maybe_decode_ascii)
#       120    0.000    0.000    0.001    0.000 threading.py:242(__exit__)
#       119    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#       494    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       108    0.000    0.000    0.023    0.000 dataloader.py:317(_next_index)
#       100    0.000    0.000    0.001    0.000 <string>:12(__new__)
#       200    0.000    0.000    0.000    0.000 connection.py:83(_validate_family)
#       100    0.000    0.000    0.001    0.000 selectors.py:214(_fileobj_lookup)
#       197    0.000    0.000    0.001    0.000 __init__.py:236(__init__)
#       206    0.000    0.000    0.002    0.000 connection.py:360(_close)
#       200    0.000    0.000    0.000    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#       481    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       131    0.000    0.000    0.000    0.000 grad_mode.py:37(__enter__)
#       197    0.000    0.000    0.001    0.000 __init__.py:357(device_count)
#        91    0.000    0.000    0.001    0.000 module.py:143(register_parameter)
#       100    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         5    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#       131    0.000    0.000    0.000    0.000 grad_mode.py:137(__init__)
# ...
#        10    0.000    0.000    0.000    0.000 argparse.py:2050(_match_argument)
#         8    0.000    0.000    0.005    0.001 genericpath.py:27(isfile)
#        10    0.000    0.000    0.000    0.000 argparse.py:1822(take_action)
#         4    0.000    0.000    0.000    0.000 process.py:52(_cleanup)
#        34    0.000    0.000    0.000    0.000 argparse.py:1278(register)
#         2    0.000    0.000    0.000    0.000 posixpath.py:154(dirname)
#         5    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        40    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        70    0.000    0.000    0.000    0.000 __future__.py:18(get_overwrite_module_params_on_conversion)
#         1    0.000    0.000    2.757    2.757 dataloader.py:274(__iter__)
#        18    0.000    0.000    0.000    0.000 iostream.py:309(_is_master_process)
#         1    0.000    0.000    0.001    0.001 argparse.py:1740(parse_known_args)
#        22    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         5    0.000    0.000    0.001    0.000 context.py:84(BoundedSemaphore)
#        19    0.000    0.000    0.000    0.000 argparse.py:1555(_add_action)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#        53    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#        26    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#         2    0.000    0.000    0.000    0.000 posixpath.py:338(normpath)
#        32    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        11    0.000    0.000    0.003    0.000 synchronize.py:161(__init__)
#         4    0.000    0.000    0.000    0.000 dataloader.py:849(_shutdown_worker)
#         7    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        19    0.000    0.000    0.000    0.000 argparse.py:2352(_get_formatter)
#         4    0.000    0.000    0.001    0.000 queues.py:131(close)
#        11    0.000    0.000    0.000    0.000 module.py:182(add_module)
#        19    0.000    0.000    0.000    0.000 argparse.py:1713(_add_action)
#        10    0.000    0.000    0.000    0.000 argparse.py:2190(_get_nargs_pattern)
#        37    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 signal_handling.py:47(_set_SIGCHLD_handler)
#        18    0.000    0.000    0.000    0.000 argparse.py:835(__init__)
#        19    0.000    0.000    0.000    0.000 argparse.py:1480(_pop_action_class)
#        19    0.000    0.000    0.000    0.000 argparse.py:564(_metavar_formatter)
#        67    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method torch._C._error_if_any_worker_fails}
#         1    0.000    0.000    0.000    0.000 dataloader.py:120(__init__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:301(__init__)
#        45    0.000    0.000    0.000    0.000 util.py:48(debug)
#        20    0.000    0.000    0.000    0.000 argparse.py:2087(_parse_optional)
#        45    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        53    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        68    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 process.py:190(ident)
#        19    0.000    0.000    0.000    0.000 argparse.py:793(__init__)
#         1    0.000    0.000    0.000    0.000 linear.py:68(__init__)
#         1    0.000    0.000    0.001    0.001 argparse.py:1604(__init__)
#        12    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#        19    0.000    0.000    0.000    0.000 argparse.py:573(format)
#         1    0.000    0.000    0.016    0.016 module.py:794(load_state_dict)
#        10    0.000    0.000    0.000    0.000 argparse.py:2286(_get_value)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         1    0.000    0.000    0.000    0.000 tarfile.py:174(nti)
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        19    0.000    0.000    0.000    0.000 init.py:123(ones_)
#         1    0.000    0.000    0.131    0.131 tarfile.py:1411(__init__)
#         4    0.000    0.000    0.001    0.000 context.py:79(Semaphore)
#        27    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:287(notify_all)
#         6    0.000    0.000    0.000    0.000 locale.py:379(normalize)
#     14/13    0.000    0.000    0.000    0.000 dataloader.py:267(__setattr__)
#         5    0.000    0.000    0.000    0.000 dataloader.py:703(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method empty}
#        19    0.000    0.000    0.000    0.000 argparse.py:1493(_check_conflict)
#         5    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#        43    0.000    0.000    0.000    0.000 {method 'islower' of 'str' objects}
#        19    0.000    0.000    0.000    0.000 argparse.py:202(__init__)
#        10    0.000    0.000    0.000    0.000 re.py:169(match)
#         7    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        29    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#        20    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         2    0.000    0.000    0.000    0.000 argparse.py:1533(__init__)
#         9    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        40    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:94(__enter__)
#         1    0.000    0.000    0.131    0.131 tarfile.py:2276(next)
#         1    0.000    0.000    0.001    0.001 zipfile.py:257(_EndRecData)
#         1    0.000    0.000    0.000    0.000 tarfile.py:1024(frombuf)
#         1    0.000    0.000    0.131    0.131 tarfile.py:1613(taropen)
#        19    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C.LongStorageBase' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:345(set)
#         1    0.000    0.000    0.000    0.000 vision.py:9(__init__)
#        10    0.000    0.000    0.000    0.000 context.py:232(get_context)
#        11    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#         2    0.000    0.000    0.000    0.000 posixpath.py:232(expanduser)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#        18    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        19    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 sampler.py:61(__iter__)
#         1    0.000    0.000    0.000    0.000 linear.py:79(reset_parameters)
#         5    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 argparse.py:864(__call__)
#         3    0.000    0.000    0.000    0.000 gettext.py:572(dgettext)
#         1    0.000    0.000    0.131    0.131 serialization.py:455(legacy_load)
#         8    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#         4    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#         2    0.000    0.000    0.000    0.000 posixpath.py:376(abspath)
#         1    0.000    0.000    0.131    0.131 tarfile.py:1087(fromtarfile)
#         1    0.000    0.000    0.007    0.007 shape_base.py:182(vstack)
#         1    0.000    0.000    0.001    0.001 Attack_Foolbox_ResNet20.py:97(__init__)
#        21    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        10    0.000    0.000    0.000    0.000 argparse.py:1950(<listcomp>)
#         8    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISREG}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         1    0.000    0.000    0.131    0.131 tarfile.py:1522(open)
#         1    0.000    0.000    0.000    0.000 os.py:672(__setitem__)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        11    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:212(__init__)
#         3    0.000    0.000    0.000    0.000 argparse.py:1484(_get_handler)
#         1    0.000    0.000   67.515   67.515 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 pooling.py:539(__init__)
#         1    0.000    0.000    0.006    0.006 module.py:297(cuda)
#         1    0.000    0.000    0.000    0.000 serialization.py:179(_check_seekable)
#         1    0.000    0.000    0.000    0.000 shape_base.py:63(atleast_2d)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 context.py:74(Condition)
#         1    0.000    0.000    0.001    0.001 context.py:89(Event)
#         4    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#         1    0.000    0.000    0.000    0.000 synchronize.py:229(__enter__)
#         5    0.000    0.000    0.001    0.000 synchronize.py:144(__init__)
#         1    0.000    0.000    0.024    0.024 nagpreresnet_learned_v2.py:188(nagpreresnet_learned_v2)
#         1    0.000    0.000    0.000    0.000 dataloader.py:239(multiprocessing_context)
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 argparse.py:1354(add_argument_group)
#        10    0.000    0.000    0.000    0.000 argparse.py:2312(_check_value)
#         3    0.000    0.000    0.000    0.000 gettext.py:611(gettext)
#         4    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        10    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#         4    0.000    0.000    0.001    0.000 synchronize.py:125(__init__)
#         1    0.000    0.000    0.000    0.000 cifar.py:132(__len__)
#         1    0.000    0.000    0.000    0.000 syspathcontext.py:55(__exit__)
#         8    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#         1    0.000    0.000    0.000    0.000 argparse.py:1011(__init__)
#         1    0.000    0.000    0.000    0.000 argparse.py:1920(consume_positionals)
#         3    0.000    0.000    0.000    0.000 os.py:746(decode)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:23(getpreferredencoding)
#         4    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 cifar.py:108(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 sampler.py:182(__init__)
#         1    0.000    0.000    0.001    0.001 zipfile.py:198(is_zipfile)
#         1    0.000    0.000    0.000    0.000 numeric.py:495(asanyarray)
#         1    0.000    0.000    0.000    0.000 syspathcontext.py:48(__enter__)
#         1    0.000    0.000    0.000    0.000 builtin_trap.py:46(__exit__)
#         1    0.000    0.000    0.001    0.001 argparse.py:1733(parse_args)
#         3    0.000    0.000    0.000    0.000 gettext.py:506(translation)
#         4    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#         2    0.000    0.000    0.000    0.000 posixpath.py:64(isabs)
#         1    0.000    0.000    0.000    0.000 posixpath.py:144(basename)
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'bytes' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         2    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._remove_worker_pids}
#         1    0.000    0.000    0.001    0.001 synchronize.py:334(__init__)
#         1    0.000    0.000    0.000    0.000 init.py:12(_no_grad_uniform_)
#         1    0.000    0.000    0.001    0.001 zipfile.py:190(_check_zipfile)
#         1    0.000    0.000    0.000    0.000 serialization.py:155(_is_compressed_file)
#         1    0.000    0.000    0.000    0.000 serialization.py:163(_should_read_directly)
#         1    0.000    0.000    0.000    0.000 tarfile.py:166(nts)
#         1    0.000    0.000    0.000    0.000 shape_base.py:234(<listcomp>)
#         4    0.000    0.000    0.000    0.000 process.py:162(daemon)
#         1    0.000    0.000    0.000    0.000 codecs.py:259(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:308(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#         1    0.000    0.000    0.000    0.000 synchronize.py:232(__exit__)
#         3    0.000    0.000    0.000    0.000 dataloader.py:280(_auto_collation)
#         1    0.000    0.000    0.000    0.000 argparse.py:2071(_match_arguments_partial)
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#         6    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:235(_make_methods)
#         1    0.000    0.000    0.000    0.000 synchronize.py:97(__exit__)
#         1    0.000    0.000    0.000    0.000 attack_toolbox.py:23(__init__)
#         1    0.000    0.000    0.000    0.000 transforms.py:56(__init__)
#         1    0.000    0.000    0.000    0.000 sampler.py:58(__init__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:284(_index_sampler)
#         1    0.000    0.000    0.000    0.000 dataloader.py:925(__del__)
#         1    0.000    0.000    0.000    0.000 init.py:74(uniform_)
#         1    0.000    0.000    0.001    0.001 module.py:1073(eval)
#         1    0.000    0.000    0.000    0.000 tarfile.py:2363(_check)
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 Attack_Foolbox_ResNet20.py:96(PytorchModel)
#         1    0.000    0.000    0.000    0.000 builtin_trap.py:39(__enter__)
#         1    0.000    0.000    0.000    0.000 argparse.py:1726(<listcomp>)
#         1    0.000    0.000    0.000    0.000 argparse.py:1725(_get_positional_actions)
#         1    0.000    0.000    0.000    0.000 traitlets.py:545(__get__)
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 vision.py:55(__init__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:235(multiprocessing_context)
#         1    0.000    0.000    0.000    0.000 syspathcontext.py:45(__init__)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_mine' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 argparse.py:1211(__init__)
#         1    0.000    0.000    0.000    0.000 argparse.py:1642(identity)
#         1    0.000    0.000    0.000    0.000 argparse.py:595(<listcomp>)
#         1    0.000    0.000    0.000    0.000 traitlets.py:526(get)
