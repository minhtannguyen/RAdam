# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  2012
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          1474529 function calls (1303853 primitive calls) in 72.567 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   46.695    0.002   46.695    0.002 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   12.553    2.092   12.553    2.092 {built-in method numpy.core.multiarray.array}
#       500    3.829    0.008    3.829    0.008 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         1    1.447    1.447    1.447    1.447 {built-in method posix.waitpid}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  1242
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2688506 function calls (2355830 primitive calls) in 123.081 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   58.890    0.003   58.890    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#      1000   31.175    0.031   31.175    0.031 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         6   14.925    2.487   14.925    2.487 {built-in method numpy.core.multiarray.array}
#      9900    2.800    0.000    9.733    0.001 hopreresnet_learned_v2.py:39(forward)
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  1302
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2688524 function calls (2355848 primitive calls) in 123.143 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   58.642    0.003   58.642    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#      1000   31.194    0.031   31.194    0.031 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         6   15.138    2.523   15.138    2.523 {built-in method numpy.core.multiarray.array}
#      9900    2.770    0.000    9.672    0.001 hopreresnet_learned_v2.py:39(forward)
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  1159
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2688518 function calls (2355842 primitive calls) in 123.547 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   58.612    0.003   58.612    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#      1000   31.769    0.032   31.769    0.032 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         6   15.150    2.525   15.150    2.525 {built-in method numpy.core.multiarray.array}
#      9900    2.715    0.000    9.555    0.001 hopreresnet_learned_v2.py:39(forward)
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-0/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  1054
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2537483 function calls (2211407 primitive calls) in 110.966 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   59.553    0.003   59.553    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#      1000   21.524    0.022   21.524    0.022 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         6   15.197    2.533   15.197    2.533 {built-in method numpy.core.multiarray.array}
#     23100    1.856    0.000    1.856    0.000 {built-in method conv2d}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  1221
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2537478 function calls (2211402 primitive calls) in 113.139 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   60.315    0.003   60.315    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#      1000   21.552    0.022   21.552    0.022 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         6   15.783    2.630   15.783    2.630 {built-in method numpy.core.multiarray.array}
#     23100    1.932    0.000    1.932    0.000 {built-in method conv2d}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  1326
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2537484 function calls (2211408 primitive calls) in 111.894 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   60.006    0.003   60.006    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#      1000   21.730    0.022   21.730    0.022 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         6   15.104    2.517   15.104    2.517 {built-in method numpy.core.multiarray.array}
#     23100    1.903    0.000    1.903    0.000 {built-in method conv2d}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  1055
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2537474 function calls (2211398 primitive calls) in 110.868 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   59.175    0.003   59.175    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#      1000   22.028    0.022   22.028    0.022 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         6   14.765    2.461   14.765    2.461 {built-in method numpy.core.multiarray.array}
#     23100    1.854    0.000    1.854    0.000 {built-in method conv2d}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  2593
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          324374 function calls (303648 primitive calls) in 75.636 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   55.440    0.003   55.440    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   14.792    2.465   14.792    2.465 {built-in method numpy.core.multiarray.array}
#         1    1.604    1.604    1.604    1.604 {built-in method posix.waitpid}
#         1    0.647    0.647   75.630   75.630 Attack_PGD_ResNet20.py:4(<module>)
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  2254
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          324356 function calls (303630 primitive calls) in 76.221 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   55.595    0.003   55.595    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   15.176    2.529   15.176    2.529 {built-in method numpy.core.multiarray.array}
#         1    1.665    1.665    1.665    1.665 {built-in method posix.waitpid}
#         1    0.602    0.602   76.216   76.216 Attack_PGD_ResNet20.py:4(<module>)
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  2544
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          324372 function calls (303646 primitive calls) in 74.859 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   55.074    0.003   55.074    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   14.657    2.443   14.657    2.443 {built-in method numpy.core.multiarray.array}
#         1    1.462    1.462    1.462    1.462 {built-in method posix.waitpid}
#         1    0.574    0.574   74.853   74.853 Attack_PGD_ResNet20.py:4(<module>)
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  2392
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          324365 function calls (303639 primitive calls) in 74.759 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   54.440    0.003   54.440    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   15.005    2.501   15.005    2.501 {built-in method numpy.core.multiarray.array}
#         1    1.489    1.489    1.489    1.489 {built-in method posix.waitpid}
#         1    0.587    0.587   74.754   74.754 Attack_PGD_ResNet20.py:4(<module>)
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-0/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  2126
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          312823 function calls (292697 primitive calls) in 75.036 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   54.972    0.003   54.972    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   15.224    2.537   15.224    2.537 {built-in method numpy.core.multiarray.array}
#         1    1.495    1.495    1.495    1.495 {built-in method posix.waitpid}
#         1    0.580    0.580   75.031   75.031 Attack_PGD_ResNet20.py:4(<module>)
#         1    0.486    0.486    0.486    0.486 {built-in method posix.fork}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  2117
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          312828 function calls (292702 primitive calls) in 74.549 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   55.146    0.003   55.146    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   14.635    2.439   14.635    2.439 {built-in method numpy.core.multiarray.array}
#         1    1.478    1.478    1.478    1.478 {built-in method posix.waitpid}
#         1    0.558    0.558   74.543   74.543 Attack_PGD_ResNet20.py:4(<module>)
#         1    0.508    0.508    0.508    0.508 {built-in method posix.fork}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  2677
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          312818 function calls (292692 primitive calls) in 75.633 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   55.756    0.003   55.756    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   15.109    2.518   15.109    2.518 {built-in method numpy.core.multiarray.array}
#         1    1.485    1.485    1.485    1.485 {built-in method posix.waitpid}
#         1    0.572    0.572   75.627   75.627 Attack_PGD_ResNet20.py:4(<module>)
#         1    0.495    0.495    0.495    0.495 {built-in method posix.fork}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method fgsm --epsilon 0.031
#
#
#
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  2003
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          312825 function calls (292699 primitive calls) in 76.195 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20100   55.979    0.003   55.979    0.003 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   15.201    2.534   15.201    2.534 {built-in method numpy.core.multiarray.array}
#         1    1.500    1.500    1.500    1.500 {built-in method posix.waitpid}
#         1    0.573    0.573   76.188   76.188 Attack_PGD_ResNet20.py:4(<module>)
#         1    0.521    0.521    0.521    0.521 {built-in method posix.fork}
# ...

# %%
# %run -p Attack_PGD_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar" -a "hopreresnet_learned_v2" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method clean --epsilon 0.003
#
#
#
# Out:
# ==> creating model 'hopreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  200
# /tanresults/experiments-horesnet/cifar10-hopreresnet_learned_v220-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  7120
# [(0,), (0,), (0,), (0,), (0,)]
#          113838 function calls (109312 primitive calls) in 2.923 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       403    1.796    0.004    1.796    0.004 {method 'acquire' of '_thread.lock' objects}
#       181    0.282    0.002    0.282    0.002 {method 'update' of '_hashlib.HASH' objects}
#       450    0.122    0.000    0.398    0.001 hopreresnet_learned_v2.py:39(forward)
#         1    0.085    0.085    0.085    0.085 {built-in method posix.waitpid}
#      1150    0.085    0.000    0.085    0.000 {built-in method conv2d}
# ...
