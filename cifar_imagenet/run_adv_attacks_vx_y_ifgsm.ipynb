# %%
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar" -a "preresnet" --block-name "basicblock" --feature_vec "x" --dataset "cifar10" --eta 1.0 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.999 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.99 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.95 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.9 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.7 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.5 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.3 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.1 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.01-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.01 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.001-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.0001-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet_learned" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0

# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# %run -p Attack_Foolbox_ResNet20.py --checkpoint "/tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar" -a "nagpreresnet_learned_v2" --block-name "basicblock" --feature_vec "y" --dataset "cifar10" --eta 0.0001 --depth 20 --method ifgsm --epsilon 0.031 --gpu-id 0
# Out:
# ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4755
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4708
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4723
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'preresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-preresnet20-basicblock-eta-1.0-x-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4724
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4666
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4731
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4715
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4717
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.999-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4649
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4658
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4668
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4693
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4712
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4658
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4686
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4683
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4701
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4714
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.95-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4692
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4703
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4721
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4702
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4677
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.9-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4680
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4680
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4722
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4731
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4720
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.7-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4722
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4687
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4751
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4727
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4709
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.5-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4695
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4715
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4747
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4716
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4726
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.3-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4713
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4739
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4743
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4776
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4743
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet20-basicblock-eta-0.1-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4735
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet'
# ==> Resuming from checkpoint..
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tancode/repos/RAdam/cifar_imagenet/Attack_Foolbox_ResNet20.py in <module>
#     235     # Load the model
#     236     print('==> Resuming from checkpoint..')
# --> 237     assert os.path.isfile(opt.checkpoint), 'Error: no checkpoint directory found!'
#     238     opt.checkpoint_dir = os.path.dirname(opt.checkpoint)
#     239     checkpoint = torch.load(opt.checkpoint)
#
# AssertionError: Error: no checkpoint directory found!
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4687
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4782
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4720
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4706
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned20-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4711
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-0/model_best.pth.tar
# Number of correctly classified images:  4693
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-1/model_best.pth.tar
# Number of correctly classified images:  4750
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-2/model_best.pth.tar
# Number of correctly classified images:  4734
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-3/model_best.pth.tar
# Number of correctly classified images:  4795
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#  ==> creating model 'nagpreresnet_learned_v2'
# ==> Resuming from checkpoint..
# ==> Load the clean image
# Batch size of the test set:  100
# /tanresults/experiments-horesnet/cifar10-nagpreresnet_learned_v220-basicblock-eta-0.99-y-baolr-pgd-seed-4/model_best.pth.tar
# Number of correctly classified images:  4725
# [(10000, 3, 32, 32), (10000, 3, 32, 32), (10000, 3, 32, 32), (10000,), (10000,)]
#          2388123 function calls (2213381 primitive calls) in 76.076 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     20300   28.449    0.001   28.449    0.001 {method 'cpu' of 'torch._C._TensorBase' objects}
#         6   15.040    2.507   15.040    2.507 {built-in method numpy.core.multiarray.array}
#      2000   12.407    0.006   12.407    0.006 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     48300    3.539    0.000    3.539    0.000 {built-in method conv2d}
#     18900    2.378    0.000   11.468    0.001 nagpreresnet_learned_v2.py:39(forward)
#         4    2.268    0.567    2.268    0.567 {built-in method posix.fork}
#     39900    2.059    0.000    2.059    0.000 {built-in method batch_norm}
#        10    1.756    0.176    1.756    0.176 {built-in method posix.waitpid}
# 170000/4100    1.255    0.000   12.993    0.003 module.py:537(__call__)
#     39900    0.944    0.000    0.944    0.000 {built-in method relu_}
#         1    0.577    0.577   76.073   76.073 Attack_Foolbox_ResNet20.py:4(<module>)
#    426460    0.505    0.000    0.509    0.000 module.py:577(__getattr__)
#       100    0.459    0.005   26.422    0.264 attack_toolbox.py:35(pgd_whitebox)
#     39900    0.326    0.000    2.857    0.000 batchnorm.py:58(forward)
#      1781    0.312    0.000    0.312    0.000 {method 'update' of '_hashlib.HASH' objects}
#       123    0.295    0.002    0.295    0.002 {method 'uniform_' of 'torch._C._TensorBase' objects}
#    170000    0.254    0.000    0.254    0.000 {built-in method torch._C._get_tracing_state}
#     48300    0.188    0.000    3.760    0.000 conv.py:332(conv2d_forward)
#    354767    0.183    0.000    0.183    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      6000    0.179    0.000    0.179    0.000 {built-in method clamp}
#     39900    0.163    0.000    2.310    0.000 functional.py:1629(batch_norm)
#     48300    0.142    0.000    3.946    0.000 conv.py:342(forward)
# 14700/6300    0.116    0.000   11.800    0.002 container.py:90(forward)
#      2100    0.110    0.000    0.110    0.000 {built-in method addmm}
# 192479/192478    0.108    0.000    0.108    0.000 {built-in method builtins.len}
#     25219    0.101    0.000    0.162    0.000 module.py:593(__setattr__)
#      2627    0.091    0.000    0.091    0.000 {method 'cuda' of 'torch._C._TensorBase' objects}
#      2100    0.090    0.000   12.762    0.006 nagpreresnet_learned_v2.py:165(forward)
#     39900    0.088    0.000    1.112    0.000 activation.py:93(forward)
#     39900    0.080    0.000    1.024    0.000 functional.py:903(relu)
#      2000    0.078    0.000    0.078    0.000 {method 'sign' of 'torch._C._TensorBase' objects}
#      2000    0.068    0.000    0.068    0.000 {built-in method torch._C._nn.nll_loss}
#       192    0.063    0.000    0.063    0.000 {method 'read' of '_io.BufferedReader' objects}
#      2000    0.061    0.000    0.061    0.000 {method 'log_softmax' of 'torch._C._TensorBase' objects}
#     39900    0.059    0.000    0.087    0.000 batchnorm.py:241(_check_input_dim)
#      2100    0.059    0.000    0.059    0.000 {built-in method torch._C._nn.avg_pool2d}
#     20300    0.056    0.000    0.056    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#     20000    0.056    0.000    0.056    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#     39900    0.055    0.000    0.087    0.000 __init__.py:461(__get__)
#      2000    0.054    0.000    0.054    0.000 {built-in method ones_like}
#      1400    0.042    0.000    0.042    0.000 {built-in method posix.read}
#     64284    0.042    0.000    0.042    0.000 {method 'append' of 'list' objects}
#     72173    0.041    0.000    0.042    0.000 {built-in method builtins.isinstance}
#         6    0.041    0.007    0.041    0.007 {built-in method _pickle.load}
#       100    0.039    0.000    0.039    0.000 {method 'poll' of 'select.poll' objects}
#     75821    0.036    0.000    0.036    0.000 {method 'get' of 'dict' objects}
#      2000    0.036    0.000    0.057    0.000 optimizer.py:176(add_param_group)
#     39900    0.033    0.000    0.033    0.000 {built-in method torch._C._get_cudnn_enabled}
#     44044    0.031    0.000    0.031    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#      2000    0.026    0.000    0.098    0.000 optimizer.py:32(__init__)
#      2100    0.025    0.000    0.025    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#      2068    0.023    0.000    0.148    0.000 module.py:77(_construct)
#      2000    0.020    0.000   12.305    0.006 Attack_Foolbox_ResNet20.py:104(predict)
#      2100    0.020    0.000    0.020    0.000 {method 't' of 'torch._C._TensorBase' objects}
#      2000    0.019    0.000    0.080    0.000 __init__.py:20(_make_grads)
#      2000    0.017    0.000   12.506    0.006 __init__.py:38(backward)
#      2000    0.016    0.000    0.114    0.000 sgd.py:51(__init__)
#      2000    0.015    0.000   12.521    0.006 tensor.py:90(backward)
#      2000    0.014    0.000    0.089    0.000 functional.py:1770(nll_loss)
#      4069    0.012    0.000    0.012    0.000 {built-in method torch._C._log_api_usage_once}
#       101    0.012    0.000    0.022    0.000 sampler.py:198(__iter__)
#      8146    0.011    0.000    0.011    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#      2100    0.011    0.000    0.143    0.000 functional.py:1354(linear)
#       800    0.011    0.000    0.011    0.000 {built-in method posix.write}
#       200    0.011    0.000    0.011    0.000 {method 'recvmsg' of '_socket.socket' objects}
#      2000    0.010    0.000    0.177    0.000 loss.py:914(forward)
#      2100    0.010    0.000    0.156    0.000 linear.py:86(forward)
#        12    0.010    0.001    0.010    0.001 {built-in method io.open}
#      3240    0.009    0.000    0.021    0.000 {built-in method builtins.hasattr}
#      2000    0.008    0.000    0.164    0.000 functional.py:1950(cross_entropy)
#      2058    0.008    0.000    0.028    0.000 module.py:105(register_buffer)
#      2001    0.008    0.000    0.235    0.000 loss.py:909(__init__)
#     10040    0.008    0.000    0.008    0.000 {method 'setdefault' of 'dict' objects}
#       416    0.008    0.000    0.008    0.000 {built-in method tensor}
#       200    0.008    0.000    0.008    0.000 {method 'connect' of '_socket.socket' objects}
#         1    0.007    0.007    0.007    0.007 {built-in method numpy.core.multiarray.concatenate}
#      2000    0.007    0.000    0.017    0.000 grad_mode.py:88(__exit__)
#      2001    0.007    0.000    0.215    0.000 loss.py:18(__init__)
#      2001    0.007    0.000    0.180    0.000 loss.py:9(__init__)
#      2131    0.007    0.000    0.010    0.000 grad_mode.py:137(__init__)
#       100    0.006    0.000    0.200    0.002 {built-in method _pickle.loads}
#      2100    0.006    0.000    0.065    0.000 pooling.py:549(forward)
#        67    0.006    0.000    0.014    0.000 module.py:718(_load_from_state_dict)
#       200    0.006    0.000    0.006    0.000 {method 'acquire' of '_thread.lock' objects}
#       400    0.006    0.000    0.015    0.000 hmac.py:26(__init__)
#       700    0.006    0.000    0.057    0.000 connection.py:406(_recv_bytes)
#      1400    0.006    0.000    0.050    0.000 connection.py:374(_recv)
#      2000    0.006    0.000    0.009    0.000 grad_mode.py:84(__enter__)
#        20    0.005    0.000    0.005    0.000 {built-in method posix.stat}
#      2068    0.005    0.000    0.165    0.000 module.py:71(__init__)
#      2000    0.005    0.000    0.066    0.000 functional.py:1296(log_softmax)
#       400    0.004    0.000    0.004    0.000 socket.py:139(__init__)
#      9217    0.004    0.000    0.004    0.000 {method 'startswith' of 'str' objects}
#       200    0.004    0.000    0.020    0.000 connection.py:607(SocketClient)
#      4262    0.004    0.000    0.004    0.000 {built-in method torch._C.is_grad_enabled}
#      2021    0.004    0.000    0.004    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#       200    0.004    0.000    0.184    0.001 reductions.py:273(rebuild_storage_fd)
#       600    0.004    0.000    0.018    0.000 connection.py:181(send_bytes)
#       200    0.003    0.000    0.142    0.001 resource_sharer.py:82(get_connection)
#      2161    0.003    0.000    0.003    0.000 {method 'format' of 'str' objects}
#       397    0.003    0.000    0.003    0.000 {method 'set_' of 'torch._C._TensorBase' objects}
#      2000    0.003    0.000    0.003    0.000 optimizer.py:159(zero_grad)
#       200    0.003    0.000    0.071    0.000 connection.py:729(answer_challenge)
#      2000    0.003    0.000    0.005    0.000 tensor.py:392(__hash__)
#       700    0.003    0.000    0.061    0.000 connection.py:208(recv_bytes)
#       800    0.003    0.000    0.017    0.000 connection.py:390(_send_bytes)
#       127    0.003    0.000    0.003    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#       200    0.003    0.000    0.015    0.000 reduction.py:149(recvfds)
#        21    0.003    0.000    0.003    0.000 {method 'normal_' of 'torch._C._TensorBase' objects}
#      4262    0.003    0.000    0.003    0.000 {built-in method torch._C.set_grad_enabled}
#       100    0.003    0.000    0.261    0.003 queues.py:91(get)
#       100    0.003    0.000    0.003    0.000 {built-in method _new_shared_fd}
#       800    0.003    0.000    0.003    0.000 {built-in method _hashlib.new}
#       178    0.003    0.000    0.003    0.000 {method '_set_from_file' of 'torch._C.CudaFloatStorageBase' objects}
#       197    0.002    0.000    0.008    0.000 serialization.py:93(_cuda_deserialize)
#         1    0.002    0.002    0.002    0.002 {built-in method builtins.compile}
#       414    0.002    0.000    0.002    0.000 {built-in method posix.close}
#       200    0.002    0.000    0.029    0.000 connection.py:716(deliver_challenge)
#       397    0.002    0.000    0.013    0.000 _utils.py:128(_rebuild_tensor)
#       200    0.002    0.000    0.004    0.000 reduction.py:38(__init__)
#       100    0.002    0.000    0.050    0.000 connection.py:897(wait)
#       200    0.002    0.000    0.124    0.001 connection.py:478(Client)
#       400    0.002    0.000    0.002    0.000 {built-in method posix.fstat}
#       101    0.002    0.000    2.049    0.020 dataloader.py:775(__next__)
#       115    0.002    0.000    0.002    0.000 {method 'release' of '_thread.lock' objects}
#       800    0.002    0.000    0.013    0.000 connection.py:365(_send)
#      2000    0.002    0.000    0.002    0.000 _reduction.py:6(get_enum)
#       200    0.002    0.000    0.167    0.001 resource_sharer.py:55(detach)
#       108    0.002    0.000    0.034    0.000 dataloader.py:823(_try_put_index)
#       104    0.002    0.000    0.011    0.000 queues.py:80(put)
#       200    0.002    0.000    0.020    0.000 reduction.py:179(recv_handle)
#         7    0.002    0.000    0.379    0.054 utils.py:24(calculate_md5)
#      2027    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#      2069    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#       200    0.002    0.000    0.002    0.000 {method 'update' of 'dict' objects}
#        36    0.002    0.000    0.002    0.000 socket.py:342(send)
#        20    0.001    0.000    0.004    0.000 synchronize.py:50(__init__)
#       800    0.001    0.000    0.005    0.000 hmac.py:52(<lambda>)
#         1    0.001    0.001    0.016    0.016 {method 'load' of '_pickle.Unpickler' objects}
#       197    0.001    0.000    0.011    0.000 serialization.py:520(persistent_load)
#       200    0.001    0.000    0.010    0.000 reductions.py:79(rebuild_tensor)
#       200    0.001    0.000    0.007    0.000 reduction.py:48(dumps)
#      2000    0.001    0.000    0.001    0.000 {method 'isdisjoint' of 'set' objects}
#       800    0.001    0.000    0.004    0.000 hashlib.py:139(__hash_new)
#       100    0.001    0.000    0.001    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#       200    0.001    0.000    0.004    0.000 reductions.py:48(__setitem__)
#      1900    0.001    0.000    0.001    0.000 connection.py:134(_check_closed)
#      1400    0.001    0.000    0.001    0.000 {method 'write' of '_io.BytesIO' objects}
#       210    0.001    0.000    0.001    0.000 connection.py:117(__init__)
#       100    0.001    0.000    0.041    0.000 selectors.py:365(select)
#       200    0.001    0.000    0.001    0.000 socket.py:419(detach)
#         2    0.001    0.001    0.002    0.001 reductions.py:53(free_dead_references)
#       200    0.001    0.000    0.012    0.000 connection.py:202(send)
#       400    0.001    0.000    0.002    0.000 hmac.py:108(_current)
#       400    0.001    0.000    0.016    0.000 hmac.py:133(new)
#       100    0.001    0.000    0.003    0.000 selectors.py:233(register)
#       108    0.001    0.000    0.003    0.000 threading.py:334(notify)
#       700    0.001    0.000    0.001    0.000 {built-in method _struct.unpack}
#       200    0.001    0.000    0.001    0.000 {built-in method posix.urandom}
#         4    0.001    0.000    2.269    0.567 popen_fork.py:63(_launch)
#      67/1    0.001    0.000    0.006    0.006 module.py:206(_apply)
#       200    0.001    0.000    0.001    0.000 {method 'dump' of '_pickle.Pickler' objects}
#       197    0.001    0.000    0.003    0.000 serialization.py:68(validate_cuda_device)
#       400    0.001    0.000    0.004    0.000 hmac.py:117(digest)
#       208    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       800    0.001    0.000    0.001    0.000 {method 'digest' of '_hashlib.HASH' objects}
#       120    0.001    0.000    0.001    0.000 {method '__enter__' of '_thread.lock' objects}
#       395    0.001    0.000    0.002    0.000 __init__.py:62(is_available)
#       400    0.001    0.000    0.001    0.000 connection.py:95(address_type)
#       200    0.001    0.000    0.001    0.000 reductions.py:266(storage_from_cache)
#      1400    0.001    0.000    0.001    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#       800    0.001    0.000    0.001    0.000 connection.py:138(_check_readable)
#       400    0.001    0.000    0.003    0.000 reductions.py:258(fd_id)
#       100    0.001    0.000    0.051    0.001 connection.py:253(poll)
#       100    0.001    0.000    0.002    0.000 selectors.py:346(__init__)
#       800    0.001    0.000    0.001    0.000 {method 'translate' of 'bytes' objects}
#       236    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#       100    0.001    0.000    0.050    0.001 connection.py:413(_poll)
#         1    0.001    0.001    2.289    2.289 dataloader.py:635(__init__)
#       200    0.001    0.000    0.001    0.000 reductions.py:26(__init__)
#       800    0.001    0.000    0.001    0.000 {built-in method _struct.pack}
#       400    0.001    0.000    0.002    0.000 socket.py:151(__exit__)
#       100    0.001    0.000    0.261    0.003 dataloader.py:711(_try_get_data)
#       100    0.001    0.000    0.028    0.000 dataloader.py:842(_process_data)
#       200    0.001    0.000    0.002    0.000 socket.py:454(fromfd)
#       100    0.001    0.000    0.001    0.000 selectors.py:208(__init__)
#       269    0.001    0.000    0.024    0.000 {built-in method builtins.next}
#       100    0.001    0.000    0.004    0.000 selectors.py:350(register)
#        19    0.001    0.000    0.005    0.000 batchnorm.py:19(__init__)
#       719    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#       204    0.001    0.000    0.003    0.000 connection.py:173(close)
#       100    0.001    0.000    0.001    0.000 selectors.py:20(_fileobj_to_fd)
#       400    0.001    0.000    0.001    0.000 hmac.py:90(update)
#    309/68    0.001    0.000    0.001    0.000 module.py:1015(named_modules)
#       239    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        21    0.000    0.000    0.007    0.000 conv.py:18(__init__)
#       800    0.000    0.000    0.000    0.000 connection.py:142(_check_writable)
#       197    0.000    0.000    0.001    0.000 __init__.py:240(__enter__)
#       300    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#       197    0.000    0.000    0.009    0.000 serialization.py:117(default_restore_location)
#       200    0.000    0.000    0.001    0.000 socket.py:413(close)
#         1    0.000    0.000   76.077   76.077 py3compat.py:184(execfile)
#       204    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       100    0.000    0.000    0.002    0.000 fromnumeric.py:943(argmax)
#       200    0.000    0.000    0.003    0.000 connection.py:262(__exit__)
#       400    0.000    0.000    0.000    0.000 {method 'ljust' of 'bytes' objects}
#        23    0.000    0.000    0.001    0.000 init.py:202(_calculate_fan_in_and_fan_out)
#        36    0.000    0.000    0.002    0.000 iostream.py:197(schedule)
#       275    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       100    0.000    0.000    0.262    0.003 dataloader.py:742(_get_data)
#       200    0.000    0.000    0.000    0.000 {built-in method _socket.dup}
#       188    0.000    0.000    0.061    0.000 utils.py:27(<lambda>)
#       160    0.000    0.000    0.001    0.000 random.py:255(choice)
#       100    0.000    0.000    0.002    0.000 fromnumeric.py:50(_wrapfunc)
#       300    0.000    0.000    0.001    0.000 connection.py:168(fileno)
#       120    0.000    0.000    0.001    0.000 threading.py:239(__enter__)
#       200    0.000    0.000    0.000    0.000 socket.py:409(_real_close)
#       400    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#       197    0.000    0.000    0.001    0.000 _utils.py:5(_get_device_index)
#       100    0.000    0.000    0.000    0.000 selectors.py:268(close)
#       592    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_getDeviceCount}
#       160    0.000    0.000    0.001    0.000 random.py:223(_randbelow)
#       288    0.000    0.000    0.001    0.000 reductions.py:32(expired)
#       394    0.000    0.000    0.001    0.000 serialization.py:509(maybe_decode_ascii)
#         1    0.000    0.000    0.021    0.021 nagpreresnet_learned_v2.py:114(__init__)
#       100    0.000    0.000    0.001    0.000 <string>:12(__new__)
#       200    0.000    0.000    0.000    0.000 {method 'setblocking' of '_socket.socket' objects}
#       266    0.000    0.000    0.001    0.000 module.py:968(named_children)
#        12    0.000    0.000    0.000    0.000 util.py:151(__init__)
#       236    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#      67/1    0.000    0.000    0.014    0.014 module.py:822(load)
#       197    0.000    0.000    0.004    0.000 _utils.py:134(_rebuild_tensor_v2)
# ...
#        21    0.000    0.000    0.000    0.000 {built-in method _weakref._remove_dead_weakref}
#         1    0.000    0.000    2.289    2.289 dataloader.py:274(__iter__)
#        27    0.000    0.000    0.000    0.000 os.py:742(encode)
#        45    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 dataloader.py:703(<genexpr>)
#        48    0.000    0.000    0.000    0.000 argparse.py:1282(_registry_get)
#        10    0.000    0.000    0.000    0.000 argparse.py:1822(take_action)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        10    0.000    0.000    0.000    0.000 argparse.py:2286(_get_value)
#        70    0.000    0.000    0.000    0.000 __future__.py:18(get_overwrite_module_params_on_conversion)
#         1    0.000    0.000    0.000    0.000 {built-in method empty}
#        18    0.000    0.000    0.000    0.000 iostream.py:322(_schedule_flush)
#        26    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#         8    0.000    0.000    0.005    0.001 genericpath.py:27(isfile)
#        34    0.000    0.000    0.000    0.000 argparse.py:1278(register)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._set_worker_pids}
#         4    0.000    0.000    0.000    0.000 queues.py:196(_finalize_close)
#         4    0.000    0.000    0.000    0.000 util.py:191(cancel)
#        10    0.000    0.000    0.000    0.000 argparse.py:2234(_get_values)
#        52    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#        19    0.000    0.000    0.000    0.000 argparse.py:1480(_pop_action_class)
#         1    0.000    0.000    0.001    0.001 argparse.py:1740(parse_known_args)
#        10    0.000    0.000    0.000    0.000 argparse.py:1843(consume_optional)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#        45    0.000    0.000    0.000    0.000 util.py:48(debug)
#        19    0.000    0.000    0.000    0.000 argparse.py:1713(_add_action)
#        10    0.000    0.000    0.000    0.000 argparse.py:2050(_match_argument)
#        19    0.000    0.000    0.000    0.000 init.py:137(zeros_)
#         8    0.000    0.000    0.000    0.000 process.py:83(<genexpr>)
#        19    0.000    0.000    0.000    0.000 argparse.py:2352(_get_formatter)
#        67    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method torch._C._error_if_any_worker_fails}
#         4    0.000    0.000    0.000    0.000 dataloader.py:849(_shutdown_worker)
#         4    0.000    0.000    0.001    0.000 context.py:79(Semaphore)
#        18    0.000    0.000    0.000    0.000 argparse.py:835(__init__)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        10    0.000    0.000    0.000    0.000 context.py:232(get_context)
#         1    0.000    0.000    0.001    0.001 argparse.py:1604(__init__)
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.014    0.014 module.py:794(load_state_dict)
#         4    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#        32    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        53    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 dataloader.py:120(__init__)
#        10    0.000    0.000    0.001    0.000 activation.py:89(__init__)
#         7    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        19    0.000    0.000    0.000    0.000 argparse.py:573(format)
#         1    0.000    0.000    0.000    0.000 signal_handling.py:47(_set_SIGCHLD_handler)
#     14/13    0.000    0.000    0.000    0.000 dataloader.py:267(__setattr__)
#         5    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#        19    0.000    0.000    0.000    0.000 argparse.py:202(__init__)
#        43    0.000    0.000    0.000    0.000 {method 'islower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:287(notify_all)
#         1    0.000    0.000    0.000    0.000 synchronize.py:94(__enter__)
#         2    0.000    0.000    0.000    0.000 signal_handling.py:63(handler)
#         1    0.000    0.000    0.000    0.000 dataloader.py:301(__init__)
#        27    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        29    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:345(set)
#         1    0.000    0.000    0.000    0.000 linear.py:68(__init__)
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        11    0.000    0.000    0.000    0.000 module.py:182(add_module)
#        19    0.000    0.000    0.000    0.000 argparse.py:1493(_check_conflict)
#         6    0.000    0.000    0.000    0.000 locale.py:379(normalize)
#         2    0.000    0.000    0.000    0.000 posixpath.py:338(normpath)
#         1    0.000    0.000    0.001    0.001 tarfile.py:1411(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#         4    0.000    0.000    0.000    0.000 process.py:190(ident)
#        10    0.000    0.000    0.000    0.000 argparse.py:2190(_get_nargs_pattern)
#        12    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 posixpath.py:154(dirname)
#         1    0.000    0.000    0.000    0.000 tarfile.py:174(nti)
#         7    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#        39    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.001    0.001 tarfile.py:1613(taropen)
#         1    0.000    0.000    0.001    0.001 zipfile.py:257(_EndRecData)
#        20    0.000    0.000    0.000    0.000 argparse.py:2087(_parse_optional)
#        12    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#        19    0.000    0.000    0.000    0.000 argparse.py:564(_metavar_formatter)
#        10    0.000    0.000    0.000    0.000 re.py:169(match)
#         1    0.000    0.000    0.001    0.001 serialization.py:455(legacy_load)
#         5    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 argparse.py:1533(__init__)
#         3    0.000    0.000    0.000    0.000 gettext.py:572(dgettext)
#        11    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:229(__enter__)
#         1    0.000    0.000    0.000    0.000 sampler.py:61(__iter__)
#         1    0.000    0.000    0.000    0.000 linear.py:79(reset_parameters)
#         4    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#         4    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#        19    0.000    0.000    0.000    0.000 {method 'size' of 'torch._C.LongStorageBase' objects}
#         1    0.000    0.000    0.001    0.001 tarfile.py:2276(next)
#        20    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#        19    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 context.py:89(Event)
#        10    0.000    0.000    0.000    0.000 argparse.py:864(__call__)
#        12    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#         1    0.000    0.000    0.000    0.000 os.py:672(__setitem__)
#         2    0.000    0.000    0.000    0.000 posixpath.py:232(expanduser)
#         2    0.000    0.000    0.000    0.000 posixpath.py:376(abspath)
#         8    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:212(__init__)
#         5    0.000    0.000    0.001    0.000 synchronize.py:144(__init__)
#         1    0.000    0.000    0.001    0.001 tarfile.py:1522(open)
#         1    0.000    0.000    0.000    0.000 shape_base.py:63(atleast_2d)
#         1    0.000    0.000    0.008    0.008 shape_base.py:182(vstack)
#         1    0.000    0.000    0.001    0.001 Attack_Foolbox_ResNet20.py:97(__init__)
#         2    0.000    0.000    0.000    0.000 argparse.py:1354(add_argument_group)
#         3    0.000    0.000    0.000    0.000 gettext.py:506(translation)
#         1    0.000    0.000    0.000    0.000 synchronize.py:97(__exit__)
#         1    0.000    0.000    0.000    0.000 vision.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#         3    0.000    0.000    0.000    0.000 argparse.py:1484(_get_handler)
#        10    0.000    0.000    0.000    0.000 argparse.py:1950(<listcomp>)
#        18    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 tarfile.py:1024(frombuf)
#         1    0.000    0.000    0.000    0.000 context.py:74(Condition)
#        21    0.000    0.000    0.000    0.000 context.py:186(get_context)
#        10    0.000    0.000    0.000    0.000 argparse.py:2312(_check_value)
#         4    0.000    0.000    0.000    0.000 synchronize.py:125(__init__)
#         1    0.000    0.000    0.000    0.000 pooling.py:539(__init__)
#         1    0.000    0.000    0.000    0.000 serialization.py:155(_is_compressed_file)
#         1    0.000    0.000    0.001    0.001 tarfile.py:1087(fromtarfile)
#         4    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#         1    0.000    0.000   76.078   76.078 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 posixpath.py:64(isabs)
#         4    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#         1    0.000    0.000    0.000    0.000 synchronize.py:232(__exit__)
#         1    0.000    0.000    0.000    0.000 cifar.py:132(__len__)
#         1    0.000    0.000    0.000    0.000 sampler.py:182(__init__)
#         1    0.000    0.000    0.000    0.000 numeric.py:495(asanyarray)
#         1    0.000    0.000    0.001    0.001 argparse.py:1733(parse_args)
#         1    0.000    0.000    0.000    0.000 argparse.py:1920(consume_positionals)
#         3    0.000    0.000    0.000    0.000 os.py:746(decode)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:23(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 codecs.py:308(__init__)
#         8    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISREG}
#        10    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._remove_worker_pids}
#         1    0.000    0.000    0.001    0.001 synchronize.py:334(__init__)
#         1    0.000    0.000    0.021    0.021 nagpreresnet_learned_v2.py:188(nagpreresnet_learned_v2)
#         1    0.000    0.000    0.000    0.000 cifar.py:108(<dictcomp>)
#         1    0.000    0.000    0.006    0.006 module.py:297(cuda)
#         1    0.000    0.000    0.000    0.000 serialization.py:163(_should_read_directly)
#         1    0.000    0.000    0.000    0.000 serialization.py:179(_check_seekable)
#         1    0.000    0.000    0.000    0.000 syspathcontext.py:48(__enter__)
#         1    0.000    0.000    0.000    0.000 syspathcontext.py:55(__exit__)
#         1    0.000    0.000    0.000    0.000 builtin_trap.py:46(__exit__)
#         8    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#         4    0.000    0.000    0.000    0.000 process.py:162(daemon)
#         1    0.000    0.000    0.000    0.000 argparse.py:1011(__init__)
#         3    0.000    0.000    0.000    0.000 gettext.py:611(gettext)
#         4    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         3    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 dataloader.py:280(_auto_collation)
#         1    0.000    0.000    0.000    0.000 dataloader.py:925(__del__)
#         1    0.000    0.000    0.000    0.000 init.py:12(_no_grad_uniform_)
#         1    0.000    0.000    0.001    0.001 module.py:1073(eval)
#         1    0.000    0.000    0.001    0.001 zipfile.py:198(is_zipfile)
#         1    0.000    0.000    0.000    0.000 tarfile.py:166(nts)
#         1    0.000    0.000    0.000    0.000 shape_base.py:234(<listcomp>)
#         1    0.000    0.000    0.000    0.000 Attack_Foolbox_ResNet20.py:96(PytorchModel)
#         1    0.000    0.000    0.000    0.000 argparse.py:1725(_get_positional_actions)
#         1    0.000    0.000    0.000    0.000 argparse.py:2071(_match_arguments_partial)
#         1    0.000    0.000    0.000    0.000 posixpath.py:144(basename)
#         1    0.000    0.000    0.000    0.000 codecs.py:259(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#         5    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 transforms.py:56(__init__)
#         1    0.000    0.000    0.000    0.000 vision.py:55(__init__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:239(multiprocessing_context)
#         1    0.000    0.000    0.001    0.001 zipfile.py:190(_check_zipfile)
#         1    0.000    0.000    0.000    0.000 argparse.py:1726(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:235(_make_methods)
#         1    0.000    0.000    0.000    0.000 attack_toolbox.py:23(__init__)
#         1    0.000    0.000    0.000    0.000 sampler.py:58(__init__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:284(_index_sampler)
#         1    0.000    0.000    0.000    0.000 init.py:74(uniform_)
#         1    0.000    0.000    0.000    0.000 tarfile.py:2363(_check)
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 syspathcontext.py:45(__init__)
#         1    0.000    0.000    0.000    0.000 builtin_trap.py:39(__enter__)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_mine' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 argparse.py:1211(__init__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:526(get)
#         1    0.000    0.000    0.000    0.000 traitlets.py:545(__get__)
#         1    0.000    0.000    0.000    0.000 dataloader.py:235(multiprocessing_context)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 argparse.py:1642(identity)
#         1    0.000    0.000    0.000    0.000 argparse.py:595(<listcomp>)
